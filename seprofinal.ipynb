# %%
import numpy as np 
import pandas as pd 
import seaborn as sns
import os
from sklearn.utils import shuffle

# %% [markdown]
# # Import Data

# %%
data1 = pd.read_csv("F:/NOTES/sem6- software engineering project/lab/student-mat.csv")
data2 = pd.read_csv("F:/NOTES/sem6- software engineering project/lab/student-por.csv")
data = [data1,data2]
data=pd.concat(data)
data=shuffle(data)

# %%
data=data.drop_duplicates(["school","sex","age","address","famsize","Pstatus","Medu","Fedu","Mjob","Fjob","reason","nursery","internet"])

# %% [markdown]
# # Exploratory Analysis

# %%
data.shape
# Out:
# (661, 39)

# %%
print("percentage total female : ",(data["sex"] == 'F').value_counts(normalize = True)[1]*100)
print("percentage total male : ",(data["sex"] == 'M').value_counts(normalize = True)[1]*100)
# Out:
# percentage total female :  59.001512859304086
# percentage total male :  40.998487140695914

# %%
data['school'].value_counts().plot(kind='bar')

# %%
data['school'].value_counts().plot(kind='pie')

# %%
data['sex'].value_counts().plot(kind='bar')

# %%
data['sex'].value_counts().plot(kind='pie')

# %%
data['address'].value_counts().plot(kind='bar')

# %%
data['address'].value_counts().plot(kind='pie')

# %%
data['famsize'].value_counts().plot(kind='bar')

# %%
data['famsize'].value_counts().plot(kind='pie')

# %%
data['Pstatus'].value_counts().plot(kind='bar')

# %%
data['Pstatus'].value_counts().plot(kind='pie')

# %%
data['Medu'].value_counts().plot(kind='bar')

# %%
data['Medu'].value_counts().plot(kind='pie')

# %%
data['Fedu'].value_counts().plot(kind='bar')

# %%
data['Fedu'].value_counts().plot(kind='pie')

# %%
data['Mjob'].value_counts().plot(kind='bar')

# %%
data['Mjob'].value_counts().plot(kind='pie')

# %%
data['Fjob'].value_counts().plot(kind='bar')

# %%
data['Fjob'].value_counts().plot(kind='pie')

# %%
data['reason'].value_counts().plot(kind='bar')

# %%
data['reason'].value_counts().plot(kind='pie')

# %%
data['guardian'].value_counts().plot(kind='bar')

# %%
data['guardian'].value_counts().plot(kind='pie')

# %%
data['traveltime'].value_counts().plot(kind='bar')

# %%
data['traveltime'].value_counts().plot(kind='pie')

# %%
data['studytime'].value_counts().plot(kind='bar')

# %%
data['studytime'].value_counts().plot(kind='pie')

# %%
data['failures'].value_counts().plot(kind='bar')

# %%
data['failures'].value_counts().plot(kind='pie')

# %%
data['schoolsup'].value_counts().plot(kind='bar')

# %%
data['schoolsup'].value_counts().plot(kind='pie')

# %%
data['famsup'].value_counts().plot(kind='bar')

# %%
data['famsup'].value_counts().plot(kind='pie')

# %%
data['paid'].value_counts().plot(kind='bar')

# %%
data['paid'].value_counts().plot(kind='pie')

# %%
data['activities'].value_counts().plot(kind='bar')

# %%
data['activities'].value_counts().plot(kind='pie')

# %%
data['nursery'].value_counts().plot(kind='bar')

# %%
data['nursery'].value_counts().plot(kind='pie')

# %%
data['higher'].value_counts().plot(kind='bar')

# %%
data['higher'].value_counts().plot(kind='pie')

# %%
data['internet'].value_counts().plot(kind='bar')

# %%
data['internet'].value_counts().plot(kind='pie')

# %%
data['romantic'].value_counts().plot(kind='bar')

# %%
data['romantic'].value_counts().plot(kind='pie')

# %%
data['famrel'].value_counts().plot(kind='bar')

# %%
data['famrel'].value_counts().plot(kind='pie')

# %%
data['freetime'].value_counts().plot(kind='bar')

# %%
data['freetime'].value_counts().plot(kind='pie')

# %%
data['goout'].value_counts().plot(kind='bar')

# %%
data['goout'].value_counts().plot(kind='pie')

# %%
data['Dalc'].value_counts().plot(kind='bar')

# %%
data['Dalc'].value_counts().plot(kind='pie')

# %%
data['Walc'].value_counts().plot(kind='bar')

# %%
data['health'].value_counts().plot(kind='bar')

# %%
data['health'].value_counts().plot(kind='pie')

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(data['age'],bins=7)
plt.xlabel("age")
plt.ylabel("Frequency")
# Out:
# Text(0,0.5,'Frequency')

# %%
plt.boxplot(data['age'])
plt.show()

# %%
plt.hist(data['absences'],bins=7)
plt.xlabel("absences")
plt.ylabel("Frequency")
# Out:
# Text(0,0.5,'Frequency')

# %%
plt.boxplot(data['absences'])
plt.show()

# %%
plt.hist(data['G1'],bins=7)
plt.xlabel("G1")
plt.ylabel("Frequency")
# Out:
# Text(0,0.5,'Frequency')

# %%
plt.boxplot(data['G1'])
plt.show()

# %%
plt.hist(data['G2'],bins=7)
plt.xlabel("G2")
plt.ylabel("Frequency")
# Out:
# Text(0,0.5,'Frequency')

# %%
plt.boxplot(data['G2'])
plt.show()

# %%
plt.hist(data['G3'],bins=10)
plt.xlabel("G3")
plt.ylabel("Frequency")
# Out:
# Text(0,0.5,'Frequency')

# %%
plt.boxplot(data['G3'])
plt.show()

# %%
sns.pairplot(data)

# %%
import seaborn as sns
from matplotlib.pyplot import figure
figure(figsize=(15, 15))
hmap = sns.heatmap(data.corr(), square=True, annot=True,linewidths=0.5)

# %%
#drop some features that have very less correlation values with grades
data = data.drop(["traveltime","famrel","freetime","goout","health","absences"], axis=1)

# %%
sns.swarmplot(x="internet",y="G3",hue='address',data=data)

# %%
sns.swarmplot(x="Dalc",y="G3",hue="sex",data=data)

# %%
sns.swarmplot(x="Walc",y="G3",hue="sex",data=data)

# %%
import sys
import warnings

if not sys.warnoptions:
    warnings.simplefilter("ignore")

# %% [markdown]
# # Conversions

# %%
#data cleaning(binary and onehot encodings)
data.school[data.school == 'GP'] = 1
data.school[data.school == 'MS'] = 0
data.sex[data.sex == 'M'] = 1
data.sex[data.sex == 'F'] = 0
data.address[data.address == 'U'] = 1
data.address[data.address == 'R'] = 0
data.famsize[data.famsize == 'GT3'] = 1
data.famsize[data.famsize == 'LE3'] = 0
data.Pstatus[data.Pstatus == 'T'] = 1
data.Pstatus[data.Pstatus == 'A'] = 0

# %%
cols_to_transform = [ 'Mjob','Fjob','reason','guardian' ]
data=pd.get_dummies(data,columns=cols_to_transform)

# %%
data.schoolsup[data.schoolsup == 'yes'] = 1
data.schoolsup[data.schoolsup == 'no'] = 0
data.famsup[data.famsup == 'yes'] = 1
data.famsup[data.famsup == 'no'] = 0
data.paid[data.paid == 'yes'] = 1
data.paid[data.paid == 'no'] = 0
data.activities[data.activities == 'yes'] = 1
data.activities[data.activities == 'no'] = 0
data.nursery[data.nursery == 'yes'] = 1
data.nursery[data.nursery == 'no'] = 0
data.higher[data.higher == 'yes'] = 1
data.higher[data.higher == 'no'] = 0
data.internet[data.internet == 'yes'] = 1
data.internet[data.internet == 'no'] = 0
data.romantic[data.romantic == 'yes'] = 1
data.romantic[data.romantic == 'no'] = 0
data.head(10)
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu  studytime  failures  \
# 167      1   0   17       1       1       1     4     4          1         0
# 131      1   0   18       1       1       1     2     1          2         3
# 184      1   1   16       1       1       1     3     4          1         1
# 50       1   0   16       1       0       1     2     2          2         0
# 74       1   0   16       1       1       1     3     3          2         0
# 149      1   1   15       1       0       0     2     1          1         3
# 603      0   0   18       1       1       1     1     1          2         1
# 379      0   1   18       0       1       1     2     1          1         0
# 144      1   0   16       0       1       1     1     1          1         0
# 87       1   0   15       1       1       1     4     2          3         0
#
#           ...       Fjob_other Fjob_services Fjob_teacher reason_course  \
# 167       ...                0             0            1             1
# 131       ...                1             0            0             0
# 184       ...                1             0            0             1
# 50        ...                0             1            0             1
# 74        ...                0             1            0             0
# 149       ...                1             0            0             1
# 603       ...                0             1            0             1
# 379       ...                1             0            0             0
# 144       ...                0             1            0             0
# 87        ...                1             0            0             0
#
#     reason_home reason_other reason_reputation guardian_father  \
# 167           0            0                 0               0
# 131           0            0                 1               0
# 184           0            0                 0               1
# 50            0            0                 0               0
# 74            1            0                 0               0
# 149           0            0                 0               0
# 603           0            0                 0               0
# 379           0            1                 0               0
# 144           0            0                 1               0
# 87            0            0                 1               0
#
#      guardian_mother  guardian_other
# 167                1               0
# 131                1               0
# 184                0               0
# 50                 1               0
# 74                 1               0
# 149                1               0
# 603                1               0
# 379                1               0
# 144                1               0
# 87                 1               0
#
# [10 rows x 40 columns]

# %%
#Final grades
y =  data[[ 'G3']].mean(axis=1)
data = data.drop(["G3"], axis=1)
data.head()
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu  studytime  failures  \
# 167      1   0   17       1       1       1     4     4          1         0
# 131      1   0   18       1       1       1     2     1          2         3
# 184      1   1   16       1       1       1     3     4          1         1
# 50       1   0   16       1       0       1     2     2          2         0
# 74       1   0   16       1       1       1     3     3          2         0
#
#           ...       Fjob_other Fjob_services Fjob_teacher reason_course  \
# 167       ...                0             0            1             1
# 131       ...                1             0            0             0
# 184       ...                1             0            0             1
# 50        ...                0             1            0             1
# 74        ...                0             1            0             0
#
#     reason_home reason_other reason_reputation guardian_father  \
# 167           0            0                 0               0
# 131           0            0                 1               0
# 184           0            0                 0               1
# 50            0            0                 0               0
# 74            1            0                 0               0
#
#      guardian_mother  guardian_other
# 167                1               0
# 131                1               0
# 184                0               0
# 50                 1               0
# 74                 1               0
#
# [5 rows x 39 columns]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(data,y, test_size=0.2)

# %% [markdown]
# # Models

# %%
import matplotlib.pyplot as plt
from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score
regr = linear_model.LinearRegression()
regr.fit(X_train,y_train)
y_pred = np.round(regr.predict(X_test))
meansqr=[]
Avgdiff=[]
r2=[]
meansqr.append(mean_squared_error(y_test, y_pred))
Avgdiff.append(abs(y_test-y_pred).mean())
r2.append(r2_score(y_test, y_pred))
print("Mean squared error: %.2f"% mean_squared_error(y_test, y_pred))
print("Mean difference: %.2f"% abs(y_test-y_pred).mean())
print("r2 score: %.2f"% r2_score(y_test, y_pred))
#plotting y_pred and y_test
t = np.arange(0,len(y_pred) , 1)
plt.plot(t,y_pred,t,y_test)
# Out:
# Mean squared error: 2.33
# Mean difference: 0.89
# r2 score: 0.83
# [<matplotlib.lines.Line2D at 0x1f9365dfb00>,
#  <matplotlib.lines.Line2D at 0x1f9365dff98>]

# %%
# RandomForestRegressor
from sklearn.ensemble import RandomForestRegressor
# Instantiate model with 1000 decision trees
rf = RandomForestRegressor(n_estimators = 1000, random_state = 42)
# Train the model on training data
rf.fit(X_train, y_train);
y_pred =np.round(rf.predict(X_test))
meansqr.append(mean_squared_error(y_test, y_pred))
Avgdiff.append(abs(y_test-y_pred).mean())
r2.append(r2_score(y_test, y_pred))
print("Mean squared error: %.2f"% mean_squared_error(y_test, y_pred))
print("Mean difference: %.2f"% abs(y_test-y_pred).mean())
print("r2 score: %.2f"% r2_score(y_test, y_pred))
#plotting y_pred and y_test
t = np.arange(0,len(y_pred) , 1)
plt.plot(t,y_pred,t,y_test)
# Out:
# Mean squared error: 2.51
# Mean difference: 0.92
# r2 score: 0.81
# [<matplotlib.lines.Line2D at 0x1f9373c91d0>,
#  <matplotlib.lines.Line2D at 0x1f9373c9668>]

# %%
#svm regressor
from sklearn.svm import SVR
regressor=SVR(kernel="linear",epsilon=1.0,degree=3)
regressor.fit(X_train,y_train)
y_pred=regressor.predict(X_test)
meansqr.append(mean_squared_error(y_test, y_pred))
Avgdiff.append(abs(y_test-y_pred).mean())
r2.append(r2_score(y_test, y_pred))
print("Mean squared error: %.2f"% mean_squared_error(y_test, y_pred))
print("Mean difference: %.2f"% abs(y_test-y_pred).mean())
print("r2 score: %.2f"% r2_score(y_test, y_pred))
#plotting y_pred and y_test
t = np.arange(0,len(y_pred) , 1)
plt.plot(t,y_pred,t,y_test)
# Out:
# Mean squared error: 2.06
# Mean difference: 0.86
# r2 score: 0.85
# [<matplotlib.lines.Line2D at 0x1f93743d780>,
#  <matplotlib.lines.Line2D at 0x1f93743dda0>]

# %%
#knearest neighbhors
from sklearn import neighbors
n_neighbors=5
knn=neighbors.KNeighborsRegressor(n_neighbors,weights='uniform')
knn.fit(X_train,y_train)
y_pred=knn.predict(X_test)
meansqr.append(mean_squared_error(y_test, y_pred))
Avgdiff.append(abs(y_test-y_pred).mean())
r2.append(r2_score(y_test, y_pred))
print("Mean squared error: %.2f"% mean_squared_error(y_test, y_pred))
print("Mean difference: %.2f"% abs(y_test-y_pred).mean())
print("r2 score: %.2f"% r2_score(y_test, y_pred))
#plotting y_pred and y_test
t = np.arange(0,len(y_pred) , 1)
plt.plot(t,y_pred,t,y_test)
# Out:
# Mean squared error: 2.40
# Mean difference: 1.00
# r2 score: 0.82
# [<matplotlib.lines.Line2D at 0x1f9374a9198>,
#  <matplotlib.lines.Line2D at 0x1f9374a96a0>]

# %%
objects=('LinearReg','RandForReg','SVMregg','Knn')
plt.bar(np.arange(len(meansqr)),meansqr)
plt.xticks(np.arange(len(meansqr)), objects)
plt.title('Mean Square Error')
plt.show()
plt.bar(np.arange(len(Avgdiff)),Avgdiff)
plt.xticks(np.arange(len(Avgdiff)), objects)
plt.title('Absolute Mean Error')
plt.show()
plt.bar(np.arange(len(r2)),r2)
plt.xticks(np.arange(len(r2)), objects)
plt.title('r2_score')
plt.show()

# %%
# RandomForestRegressor
from sklearn.ensemble import RandomForestRegressor
# Instantiate model with 1000 decision trees
rf = RandomForestRegressor(n_estimators = 1000, random_state = 42)
# Train the model on training data
rf.fit(X_train, y_train);
y_pred =np.round(rf.predict(X_test))
meansqr.append(mean_squared_error(y_test, y_pred))
Avgdiff.append(abs(y_test-y_pred).mean())
r2.append(r2_score(y_test, y_pred))
print("Mean squared error: %.2f"% mean_squared_error(y_test, y_pred))
print("Mean difference: %.2f"% abs(y_test-y_pred).mean())
print("r2 score: %.2f"% r2_score(y_test, y_pred))
#plotting y_pred and y_test
t = np.arange(0,len(y_pred) , 1)
plt.plot(t,y_pred,t,y_test)
